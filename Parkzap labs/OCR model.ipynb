# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16

# %%
reader = easyocr.Reader(['en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
Image("imageocr1.jpg")

# %%
output = reader.readtext('imageocr1.jpg')

# %%
output
# Out:
# [([[386, 145], [496, 145], [496, 171], [386, 171]],
#   'DL-3C',
#   0.5926580165261918),
#  ([[382, 172], [438, 172], [438, 198], [382, 198]], 'AR-', 0.9999472110163546),
#  ([[456, 172], [534, 172], [534, 202], [456, 202]],
#   '0200',
#   0.9957411289215088)]

# %%
cord = output[-1][0]

# %%
x_min, y_min = [int(min(idx)) for idx in zip(*cord)]

# %%
x_max, y_max = [int(max(idx)) for idx in zip(*cord)]

# %%
# %matplotlib inline
image = cv2.imread('imageocr1.jpg')
cv2.rectangle(image,(x_min,y_min),(x_max,y_max),(0,0,255),2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
Image("ocrimage2.jpg")

# %%
output = reader.readtext('ocrimage2.jpg')

# %%
output
# Out:
# [([[349, 379], [559, 379], [559, 415], [349, 415]],
#   'DEU371',
#   0.32054192488095884)]

# %%
cord = output[-1][0]

# %%
x_min, y_min = [int(min(idx)) for idx in zip(*cord)]

# %%
x_max, y_max = [int(max(idx)) for idx in zip(*cord)]

# %%
# %matplotlib inline
image = cv2.imread('ocrimage2.jpg')
cv2.rectangle(image,(x_min,y_min),(x_max,y_max),(0,0,255),2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
Image("ocrimage3.jpg")

# %%
output = reader.readtext('ocrimage3.jpg')

# %%
output
# Out:
# [([[542, 138], [624, 138], [624, 162], [542, 162]],
#   'Cqp',
#   0.11101881775303342),
#  ([[451, 174], [680, 174], [680, 216], [451, 216]],
#   'MIO2.CL-9798',
#   0.8137376921522969),
#  ([[730, 180], [789, 180], [789, 197], [730, 197]],
#   '20u2',
#   0.27971264719963074)]

# %%
cord = output[-1][0]

# %%
x_min, y_min = [int(min(idx)) for idx in zip(*cord)]

# %%
x_max, y_max = [int(max(idx)) for idx in zip(*cord)]

# %%
# %matplotlib inline
image = cv2.imread('ocrimage3.jpg')
cv2.rectangle(image,(x_min,y_min),(x_max,y_max),(0,0,255),2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
Image("sample.jpg")

# %%
output = reader.readtext('sample.jpg')

# %%
output
# Out:
# [([[16, 24], [166, 24], [166, 32], [16, 32]],
#   'bestseIlinb Kuthor dFthe DA Yinci Code',
#   0.05240450131879718),
#  ([[47, 37], [137, 37], [137, 73], [47, 73]], 'DAN', 0.7656443542545335),
#  ([[8, 68], [174, 68], [174, 122], [8, 122]], 'BROWN', 0.9978101923600099),
#  ([[49, 123], [153, 123], [153, 165], [49, 165]],
#   ')RIGIN',
#   0.7802156215279646)]

# %%
cord = output[-1][0]

# %%
x_min, y_min = [int(min(idx)) for idx in zip(*cord)]

# %%
x_max, y_max = [int(max(idx)) for idx in zip(*cord)]

# %%
# %matplotlib inline
image = cv2.imread('sample.jpg')
cv2.rectangle(image,(x_min,y_min),(x_max,y_max),(0,0,255),2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
